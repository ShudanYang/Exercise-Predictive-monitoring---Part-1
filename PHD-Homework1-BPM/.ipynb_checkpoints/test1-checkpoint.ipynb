# %%
# 导入必要的库
import pandas as pd

# 1. 导入事件日志作为Pandas DataFrame
event_log_df = pd.read_csv('Small.csv')

# 2. 重命名属性为"caseid, activity, ts"（如果名称不同）
event_log_df = event_log_df.rename(columns={'Case ID': 'caseid', 'Activity': 'activity', 'Complete Timestamp': 'ts'})

# 3. 创建一个事件日志，仅保留caseid、activity和ts属性
event_log_new_df = event_log_df[['caseid', 'activity', 'ts']]

# 4. 创建一个新的DataFrame，包含caseid和按时间戳排序的事件列表
new_df = pd.DataFrame(columns=['caseid', 'list_of_events_ordered_by_timestamp'])

current_case = None#跟踪当前处理的案例
events = []#事件列表

# 按caseid和ts排序事件日志
event_log_df = event_log_df.sort_values(by=['caseid', 'ts'])

# 遍历事件日志的每一行
for index, row in event_log_df.iterrows():
    case_id = row['caseid']
    activity = row['activity']
    timestamp = row['ts']

    # 如果是新案例或当前案例已结束，创建新案例
    if case_id != current_case:
        if current_case is not None:
            # 创建一个新的DataFrame，包含caseid和按时间戳排序的事件列表
            new_df = pd.concat([new_df, pd.DataFrame({'caseid': [current_case], 'list_of_events_ordered_by_timestamp': [events]})], ignore_index=True)
        current_case = case_id
        events = []
        # 将活动表示为一个字典并添加到案例的事件列表中
        event_dict = {'activity': activity, 'ts': timestamp}
        events.append(event_dict)

# 添加最后一个案例
new_df = pd.concat([new_df, pd.DataFrame({'caseid': [current_case], 'list_of_events_ordered_by_timestamp': [events]})], ignore_index=True)
print(new_df)


# 5. 增加持续时间和事件数量属性
new_df['duration'] = new_df['list_of_events_ordered_by_timestamp'].apply(lambda x: (x[-1]['ts'] - x[0]['ts']).total_seconds() if len(x) > 1 else 0)
new_df['event_number'] = new_df['list_of_events_ordered_by_timestamp'].apply(lambda x: len(x))

# 6. 找到持续时间最长和最短的案例
longest_case = new_df.loc[new_df['duration'].idxmax()]
shortest_case = new_df.loc[new_df['duration'].idxmin()]

# 7. 找到事件数量最多的案例（可能有多个）
max_event_number = new_df['event_number'].max()
longest_cases_by_events = new_df[new_df['event_number'] == max_event_number]

# 打印结果
print("Longest Case by Duration:")
print(longest_case)

print("\nShortest Case by Duration:")
print(shortest_case)

print("\nLongest Cases by Number of Events:")
print(longest_cases_by_events)
# Out:
#           caseid                list_of_events_ordered_by_timestamp
# 0         case_0  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# 1         case_1  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# 2        case_10  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# 3       case_100  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# 4      case_1000  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# ...          ...                                                ...
# 12495  case_9995  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# 12496  case_9996  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# 12497  case_9997  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# 12498  case_9998  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# 12499  case_9999  [{'activity': 'Activity A', 'ts': '1970/01/01 ...
#
# [12500 rows x 2 columns]
# Longest Case by Duration:
# caseid                                                                            case_0
# list_of_events_ordered_by_timestamp    [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# duration                                                                               0
# event_number                                                                           1
# Name: 0, dtype: object
#
# Shortest Case by Duration:
# caseid                                                                            case_0
# list_of_events_ordered_by_timestamp    [{'activity': 'Activity A', 'ts': '1970/01/01 ...
# duration                                                                               0
# event_number                                                                           1
# Name: 0, dtype: object
#
# Longest Cases by Number of Events:
#           caseid                list_of_events_ordered_by_timestamp  duration  \
# 0         case_0  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# 1         case_1  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# 2        case_10  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# 3       case_100  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# 4      case_1000  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# ...          ...                                                ...       ...
# 12495  case_9995  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# 12496  case_9996  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# 12497  case_9997  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# 12498  case_9998  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
# 12499  case_9999  [{'activity': 'Activity A', 'ts': '1970/01/01 ...         0
#
#        event_number
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 12495             1
# 12496             1
# 12497             1
# 12498             1
# 12499             1
#
# [12500 rows x 4 columns]

# %%
# 导入必要的库
import pandas as pd

# 1. 导入事件日志作为Pandas DataFrame
event_log_df = pd.read_csv('hospital_billing.csv')

# 2. 重命名属性为"caseid, activity, ts"（如果名称不同）
event_log_df = event_log_df.rename(columns={'case_id': 'caseid', 'activity': 'activity', 'timestamp': 'ts'})
#print(event_log_df)

# 3. 创建一个事件日志，仅保留caseid、activity和ts属性
event_log_new_df = event_log_df[['caseid', 'activity', 'ts']]

# 4. 创建一个新的DataFrame，包含caseid和按时间戳排序的事件列表
new_df = pd.DataFrame(columns=['caseid', 'list_of_events_ordered_by_timestamp'])

current_case = None#跟踪当前处理的案例
events = []#事件列表

# 按caseid和ts排序事件日志
event_log_df = event_log_df.sort_values(by=['caseid', 'ts'])

# 遍历事件日志的每一行
for index, row in event_log_df.iterrows():
    case_id = row['caseid']
    activity = row['activity']
    timestamp = row['ts']

    # 如果是新案例或当前案例已结束，创建新案例
    if case_id != current_case:
        if current_case is not None:
            # 创建一个新的DataFrame，包含caseid和按时间戳排序的事件列表
            new_df = pd.concat([new_df, pd.DataFrame({'caseid': [current_case], 'list_of_events_ordered_by_timestamp': [events]})], ignore_index=True)
        current_case = case_id
        events = []
        # 将活动添加到案例的事件列表中
        #events.append(activity)
        # 将活动表示为一个字典并添加到案例的事件列表中
        event_dict = {'activity': activity, 'ts': timestamp}
        events.append(event_dict)

# 添加最后一个案例
new_df = pd.concat([new_df, pd.DataFrame({'caseid': [current_case], 'list_of_events_ordered_by_timestamp': [events]})], ignore_index=True)
print(new_df)
# 5. 增加持续时间和事件数量属性
new_df['duration'] = new_df['list_of_events_ordered_by_timestamp'].apply(lambda x: (x[-1]['ts'] - x[0]['ts']).total_seconds() if len(x) > 1 else 0)
new_df['event_number'] = new_df['list_of_events_ordered_by_timestamp'].apply(lambda x: len(x))

# 6. 找到持续时间最长和最短的案例
longest_case = new_df.loc[new_df['duration'].idxmax()]
shortest_case = new_df.loc[new_df['duration'].idxmin()]

# 7. 找到事件数量最多的案例（可能有多个）
max_event_number = new_df['event_number'].max()
longest_cases_by_events = new_df[new_df['event_number'] == max_event_number]

# 打印结果
print("Longest Case by Duration:")
print(longest_case)

print("\nShortest Case by Duration:")
print(shortest_case)

print("\nLongest Cases by Number of Events:")
print(longest_cases_by_events)
# Out:
#      caseid                list_of_events_ordered_by_timestamp
# 0         A  [{'activity': 'NEW', 'ts': '2012-12-16 19:33:1...
# 1        AA  [{'activity': 'NEW', 'ts': '2012-12-26 08:50:1...
# 2       AAA  [{'activity': 'NEW', 'ts': '2013-01-26 22:56:1...
# 3       AAB  [{'activity': 'NEW', 'ts': '2013-01-03 22:55:3...
# 4       AAC  [{'activity': 'NEW', 'ts': '2013-01-08 11:37:1...
# ...     ...                                                ...
# 9995    ZZJ  [{'activity': 'NEW', 'ts': '2013-02-27 22:59:0...
# 9996    ZZK  [{'activity': 'NEW', 'ts': '2013-03-11 10:38:0...
# 9997    ZZL  [{'activity': 'NEW', 'ts': '2013-04-06 02:38:4...
# 9998    ZZM  [{'activity': 'NEW', 'ts': '2013-03-19 14:26:0...
# 9999    NaN  [{'activity': 'NEW', 'ts': '2012-12-14 22:52:3...
#
# [10000 rows x 2 columns]
# Longest Case by Duration:
# caseid                                                                                 A
# list_of_events_ordered_by_timestamp    [{'activity': 'NEW', 'ts': '2012-12-16 19:33:1...
# duration                                                                               0
# event_number                                                                           1
# Name: 0, dtype: object
#
# Shortest Case by Duration:
# caseid                                                                                 A
# list_of_events_ordered_by_timestamp    [{'activity': 'NEW', 'ts': '2012-12-16 19:33:1...
# duration                                                                               0
# event_number                                                                           1
# Name: 0, dtype: object
#
# Longest Cases by Number of Events:
#      caseid                list_of_events_ordered_by_timestamp  duration  \
# 0         A  [{'activity': 'NEW', 'ts': '2012-12-16 19:33:1...         0
# 1        AA  [{'activity': 'NEW', 'ts': '2012-12-26 08:50:1...         0
# 2       AAA  [{'activity': 'NEW', 'ts': '2013-01-26 22:56:1...         0
# 3       AAB  [{'activity': 'NEW', 'ts': '2013-01-03 22:55:3...         0
# 4       AAC  [{'activity': 'NEW', 'ts': '2013-01-08 11:37:1...         0
# ...     ...                                                ...       ...
# 9995    ZZJ  [{'activity': 'NEW', 'ts': '2013-02-27 22:59:0...         0
# 9996    ZZK  [{'activity': 'NEW', 'ts': '2013-03-11 10:38:0...         0
# 9997    ZZL  [{'activity': 'NEW', 'ts': '2013-04-06 02:38:4...         0
# 9998    ZZM  [{'activity': 'NEW', 'ts': '2013-03-19 14:26:0...         0
# 9999    NaN  [{'activity': 'NEW', 'ts': '2012-12-14 22:52:3...         0
#
#       event_number
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...            ...
# 9995             1
# 9996             1
# 9997             1
# 9998             1
# 9999             1
#
# [10000 rows x 4 columns]
